# %% [markdown]
# ## Objetivo: identificar padrões, tendências, anomalias e formular hipóteses iniciais.

# %% [markdown]
# ### Passo 1: Preparação de Dados

# %% [markdown]
# #### Passo 1.1: Limpeza dos Dados

# %% [markdown]
# #### Passo 1.2: Limpeza dos Dados

# %% [markdown]
# #### Passo 1.3: Transformação dos dados

# %% [markdown]
# ### Passo 2: Análise Inicial dos Dados

# %% [markdown]
# #### Passo 2.1: Estatísticas descritivas: Média, mediana, moda, desvios padrões e distribuições.

# %% [markdown]
# #### Passo 2.2: Análise de Dados Categóricos: Frequências, porcentagens e tabelas cruzadas.

# %% [markdown]
# ### Passo 3: Visualização dos Dados

# %% [markdown]
# #### Passo 3.1: Histogramas

# %% [markdown]
# #### Passo 3.2: Boxplots

# %% [markdown]
# #### Passo 3.3: Gráficos de dispersão

# %% [markdown]
# #### Passo 3.4: Gráficos de barras e gráficos de pizza

# %% [markdown]
# ### Passo 4: Detecção de Outliers e Anomalias

# %% [markdown]
# ### Passo 5: Correlação e Análise Multivariada

# %% [markdown]
# #### Passo 5.1: Análise de Correlação

# %% [markdown]
# #### Passo 5.2: Introdução rápida à análise multivariada

# %% [markdown]
# ### Passo 6: Geração de Hipóteses
